# %%
import ensimpl.utils as utils
import ensimpl.fetch.utils as fetch_utils
import sqlite3 


SQL_ID_GENES = '''
SELECT e.ensembl_id ensembl_id, 
       e.ensembl_id gene_id,
       e.ensembl_version gene_version,
       e.species_id gene_species_id,
       e.symbol gene_symbol,
       e.name gene_name,
       e.synonyms gene_synonyms,
       e.external_ids gene_external_ids,
       e.chromosome gene_chromosome,
       e.start_position gene_start,
       e.end_position gene_end,
       e.strand gene_strand,
       'EG' type_key
  FROM ensembl_genes e
 WHERE 1 = 1
'''

SQL_WHERE_ID = '''
  AND e.ensembl_id IN (SELECT distinct ensembl_id FROM {})
'''

SQL_ORDER_BY = ' ORDER BY e.ensembl_id'


def get_all():
    variables = {}

    conn = fetch_utils.connect_to_database('91', 'Mm')

    conn.row_factory = sqlite3.Row
    cursor = conn.cursor()

    SQL_QUERY = '{} {}'.format(SQL_ID_GENES, SQL_ORDER_BY)
    
    ret = []

    for row in cursor.execute(SQL_QUERY, variables):
        ret.append(row)

    conn.close()
    
    return ret


def get_yield():
    variables = {}

    conn = fetch_utils.connect_to_database('91', 'Mm')

    conn.row_factory = sqlite3.Row
    cursor = conn.cursor()

    SQL_QUERY = '{} {}'.format(SQL_ID_GENES, SQL_ORDER_BY)
    
    for row in cursor.execute(SQL_QUERY, variables):
        yield row
            
    conn.close()

# %%
def ResultIter(cursor, arraysize=1000):
    'An iterator that uses fetchmany to keep memory usage down'
    while True:
        results = cursor.fetchmany(arraysize)
        if not results:
            break
        for result in results:
            yield result

# %%
for a in get_yield():
    pass
print('done')

# %%
from ensimpl.fetch import genes

# %%
genes.get(version=91, species='Mm')

# %%
import ensimpl.utils as utils
import ensimpl.fetch.utils as fetch_utils

# %%
a=fetch_utils.str_to_region('1:1000-10000')

# %%
a

# %%
str(a)

# %%
a.start_position

# %%
import ensimpl.db_config as db_config

# %%
db_config.ENSIMPL_DBS

# %%
for k in db_config.ENSIMPL_DBS_DICT
    print(k)

# %%
import operator
max(db_config.ENSIMPL_DBS_DICT.items(), key=operator.itemgetter(1))[0]

# %%
max(db['version'] for db in db_config.ENSIMPL_DBS)

# %%
import ensimpl.fetch.history as history

# %%
history.get_history('ENSMUSG00000000001', 'Mm', 33)
# Out:
# [ENsimpl] [01/14/2019 07:58:19 PM] Error connecting to database: Unable to find version "33" and species "Mm"
# [ENsimpl] [01/14/2019 07:58:19 PM] Error connecting to database: Unable to find version "34" and species "Mm"
# [ENsimpl] [01/14/2019 07:58:19 PM] Error connecting to database: Unable to find version "35" and species "Mm"
# [ENsimpl] [01/14/2019 07:58:19 PM] Error connecting to database: Unable to find version "36" and species "Mm"
# [ENsimpl] [01/14/2019 07:58:19 PM] Error connecting to database: Unable to find version "37" and species "Mm"
# [ENsimpl] [01/14/2019 07:58:19 PM] Error connecting to database: Unable to find version "38" and species "Mm"
# [ENsimpl] [01/14/2019 07:58:19 PM] Error connecting to database: Unable to find version "39" and species "Mm"
# [ENsimpl] [01/14/2019 07:58:19 PM] Error connecting to database: Unable to find version "40" and species "Mm"
# [ENsimpl] [01/14/2019 07:58:19 PM] Error connecting to database: Unable to find version "41" and species "Mm"
# [ENsimpl] [01/14/2019 07:58:19 PM] Error connecting to database: Unable to find version "42" and species "Mm"
# [ENsimpl] [01/14/2019 07:58:19 PM] Error connecting to database: Unable to find version "43" and species "Mm"
# [ENsimpl] [01/14/2019 07:58:19 PM] Error connecting to database: Unable to find version "44" and species "Mm"
# [ENsimpl] [01/14/2019 07:58:19 PM] Error connecting to database: Unable to find version "45" and species "Mm"
# [ENsimpl] [01/14/2019 07:58:19 PM] Error connecting to database: Unable to find version "46" and species "Mm"
# [ENsimpl] [01/14/2019 07:58:19 PM] Error connecting to database: Unable to find version "47" and species "Mm"
# {48: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 107910199,
#    'end': 107949064,
#    'strand': '-',
#    'ensembl_version': '2',
#    'symbol': 'Gnai3',
#    'name': 'guanine nucleotide binding protein, alpha inhibiting 3',
#    'external_ids': [{'db': 'UniGene', 'db_id': 'Mm.102487'}]}},
#  49: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 107910199,
#    'end': 107949007,
#    'strand': '-',
#    'ensembl_version': '3',
#    'symbol': 'Gnai3',
#    'name': 'guanine nucleotide binding protein (G protein), alpha inhibiting 3',
#    'synonyms': ['AW208404', 'Bap29', 'Bap29'],
#    'external_ids': [{'db': 'UniGene', 'db_id': 'Mm.379342'},
#     {'db': 'EntrezGene', 'db_id': '12033'},
#     {'db': 'MGI', 'db_id': 'MGI:101917'}]}},
#  50: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 107910199,
#    'end': 107949007,
#    'strand': '-',
#    'ensembl_version': '3',
#    'symbol': 'Gnai3',
#    'name': 'guanine nucleotide binding protein (G protein), alpha inhibiting 3',
#    'synonyms': ['Bap29', 'AW208404', 'Bap29'],
#    'external_ids': [{'db': 'MGI', 'db_id': 'MGI:101917'},
#     {'db': 'EntrezGene', 'db_id': '12033'},
#     {'db': 'UniGene', 'db_id': 'Mm.379342'}]}},
#  51: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 107910199,
#    'end': 107949007,
#    'strand': '-',
#    'ensembl_version': '3',
#    'symbol': 'Gnai3',
#    'synonyms': ['AW208404', 'Bap29'],
#    'external_ids': [{'db': 'MGI', 'db_id': 'MGI:101917'},
#     {'db': 'EntrezGene', 'db_id': '12033'},
#     {'db': 'UniGene', 'db_id': 'Mm.379342'}]}},
#  52: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 107910199,
#    'end': 107949007,
#    'strand': '-',
#    'ensembl_version': '3',
#    'symbol': 'Gnai3',
#    'synonyms': ['1300013M05Rik', 'Spf', 'TAP', 'Galphai3'],
#    'external_ids': [{'db': 'EntrezGene', 'db_id': '67815'},
#     {'db': 'MGI', 'db_id': 'MGI:95773'}]}},
#  53: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 107910199,
#    'end': 107949007,
#    'strand': '-',
#    'ensembl_version': '3',
#    'symbol': 'Gnai3',
#    'synonyms': ['1300013M05Rik', 'Spf', 'TAP', 'Galphai3'],
#    'external_ids': [{'db': 'EntrezGene', 'db_id': '67815'},
#     {'db': 'MGI', 'db_id': 'MGI:95773'}]}},
#  54: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 107910199,
#    'end': 107949007,
#    'strand': '-',
#    'ensembl_version': '3',
#    'symbol': 'Gnai3',
#    'synonyms': ['1300013M05Rik', 'Spf', 'TAP'],
#    'external_ids': [{'db': 'MGI', 'db_id': 'MGI:95773'},
#     {'db': 'EntrezGene', 'db_id': '67815'}]}},
#  55: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 107910199,
#    'end': 107949007,
#    'strand': '-',
#    'ensembl_version': '3',
#    'symbol': 'Gnai3',
#    'synonyms': ['1300013M05Rik', 'Spf', 'TAP'],
#    'external_ids': [{'db': 'MGI', 'db_id': 'MGI:95773'},
#     {'db': 'EntrezGene', 'db_id': '67815'}]}},
#  56: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 107910199,
#    'end': 107949007,
#    'strand': '-',
#    'ensembl_version': '3',
#    'symbol': 'Gnai3',
#    'synonyms': ['1300013M05Rik', 'Spf', 'TAP'],
#    'external_ids': [{'db': 'MGI', 'db_id': 'MGI:95773'},
#     {'db': 'EntrezGene', 'db_id': '67815'}]}},
#  57: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 107910198,
#    'end': 107949064,
#    'strand': '-',
#    'ensembl_version': '4',
#    'symbol': 'Gnai3',
#    'external_ids': [{'db': 'MGI', 'db_id': 'MGI:95773'}]}},
#  58: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 107910198,
#    'end': 107949064,
#    'strand': '-',
#    'ensembl_version': '4',
#    'symbol': 'Gnai3',
#    'name': 'guanine nucleotide binding protein (G protein), alpha inhibiting 3 Gene',
#    'external_ids': [{'db': 'MGI', 'db_id': 'MGI:95773'}]}},
#  59: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 107910198,
#    'end': 107949064,
#    'strand': '-',
#    'ensembl_version': '4',
#    'symbol': 'Gnai3',
#    'name': 'guanine nucleotide binding protein (G protein), alpha inhibiting 3 Gene',
#    'external_ids': [{'db': 'MGI', 'db_id': 'MGI:95773'}]}},
#  60: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 107910198,
#    'end': 107949064,
#    'strand': '-',
#    'ensembl_version': '4',
#    'symbol': 'Gnai3',
#    'name': 'guanine nucleotide binding protein (G protein), alpha inhibiting 3 Gene',
#    'external_ids': [{'db': 'MGI', 'db_id': 'MGI:95773'}]}},
#  61: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 107910198,
#    'end': 107949064,
#    'strand': '-',
#    'ensembl_version': '4',
#    'symbol': 'Gnai3',
#    'name': 'guanine nucleotide binding protein (G protein), alpha inhibiting 3 Gene',
#    'external_ids': [{'db': 'MGI', 'db_id': 'MGI:95773'},
#     {'db': 'MGI', 'db_id': 'MGI:3705528'}]}},
#  62: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 107910198,
#    'end': 107949064,
#    'strand': '-',
#    'ensembl_version': '4',
#    'symbol': 'Gnai3',
#    'name': 'guanine nucleotide binding protein (G protein), alpha inhibiting 3 Gene',
#    'external_ids': [{'db': 'MGI', 'db_id': 'MGI:95773'},
#     {'db': 'MGI', 'db_id': 'MGI:3705528'}]}},
#  63: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 107910198,
#    'end': 107949064,
#    'strand': '-',
#    'ensembl_version': '4',
#    'symbol': 'Gnai3',
#    'name': 'guanine nucleotide binding protein (G protein), alpha inhibiting 3',
#    'synonyms': ['AI158965', 'AW537698', 'Galphai3', 'Gnai-3', 'Galphai3'],
#    'external_ids': [{'db': 'EntrezGene', 'db_id': '14679'},
#     {'db': 'MGI', 'db_id': 'MGI:95773'},
#     {'db': 'MGI', 'db_id': 'MGI:3705528'},
#     {'db': 'UniGene', 'db_id': 'Mm.271703'},
#     {'db': 'UniGene', 'db_id': 'Mm.391725'},
#     {'db': 'UniGene', 'db_id': 'Mm.469993'}]}},
#  64: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 107910198,
#    'end': 107949064,
#    'strand': '-',
#    'ensembl_version': '4',
#    'symbol': 'Gnai3',
#    'name': 'guanine nucleotide binding protein (G protein), alpha inhibiting 3',
#    'synonyms': ['AI158965', 'AW537698', 'Galphai3', 'Gnai-3', 'Galphai3'],
#    'external_ids': [{'db': 'EntrezGene', 'db_id': '14679'},
#     {'db': 'MGI', 'db_id': 'MGI:95773'},
#     {'db': 'UniGene', 'db_id': 'Mm.271703'},
#     {'db': 'UniGene', 'db_id': 'Mm.391725'},
#     {'db': 'UniGene', 'db_id': 'Mm.469993'}]}},
#  65: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 107910198,
#    'end': 107949064,
#    'strand': '-',
#    'ensembl_version': '4',
#    'symbol': 'Gnai3',
#    'name': 'guanine nucleotide binding protein (G protein), alpha inhibiting 3',
#    'synonyms': ['AI158965', 'AW537698', 'Galphai3', 'Gnai-3', "'Galphai3'"],
#    'external_ids': [{'db': 'EntrezGene', 'db_id': '14679'},
#     {'db': 'MGI', 'db_id': 'MGI:95773'},
#     {'db': 'UniGene', 'db_id': 'Mm.271703'},
#     {'db': 'UniGene', 'db_id': 'Mm.391725'},
#     {'db': 'UniGene', 'db_id': 'Mm.469993'}]}},
#  66: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 107910198,
#    'end': 107949064,
#    'strand': '-',
#    'ensembl_version': '4',
#    'symbol': 'Gnai3',
#    'name': 'guanine nucleotide binding protein (G protein), alpha inhibiting 3',
#    'synonyms': ['AI158965', 'AW537698', 'Galphai3', 'Gnai-3', "'Galphai3'"],
#    'external_ids': [{'db': 'EntrezGene', 'db_id': '14679'},
#     {'db': 'MGI', 'db_id': 'MGI:95773'},
#     {'db': 'UniGene', 'db_id': 'Mm.271703'},
#     {'db': 'UniGene', 'db_id': 'Mm.391725'},
#     {'db': 'UniGene', 'db_id': 'Mm.469993'}]}},
#  67: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 107910198,
#    'end': 107949064,
#    'strand': '-',
#    'ensembl_version': '4',
#    'symbol': 'Gnai3',
#    'name': 'guanine nucleotide binding protein (G protein), alpha inhibiting 3',
#    'synonyms': ['AI158965', 'AW537698', 'Galphai3', 'Gnai-3', "'Galphai3'"],
#    'external_ids': [{'db': 'EntrezGene', 'db_id': '14679'},
#     {'db': 'MGI', 'db_id': 'MGI:95773'},
#     {'db': 'UniGene', 'db_id': 'Mm.271703'},
#     {'db': 'UniGene', 'db_id': 'Mm.469993'}]}},
#  68: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 108107280,
#    'end': 108146146,
#    'strand': '-',
#    'ensembl_version': '4',
#    'symbol': 'Gnai3',
#    'name': 'guanine nucleotide binding protein (G protein), alpha inhibiting 3',
#    'synonyms': ['AI158965', 'AW537698', 'Galphai3', 'Gnai-3', 'Galphai3'],
#    'external_ids': [{'db': 'EntrezGene', 'db_id': '14679'},
#     {'db': 'MGI', 'db_id': 'MGI:95773'},
#     {'db': 'UniGene', 'db_id': 'Mm.271703'},
#     {'db': 'UniGene', 'db_id': 'Mm.469993'}]}},
#  69: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 108107280,
#    'end': 108146146,
#    'strand': '-',
#    'ensembl_version': '4',
#    'symbol': 'Gnai3',
#    'name': 'guanine nucleotide binding protein (G protein), alpha inhibiting 3',
#    'synonyms': ['AI158965', 'AW537698', 'Galphai3', 'Gnai-3', 'Galphai3'],
#    'external_ids': [{'db': 'EntrezGene', 'db_id': '14679'},
#     {'db': 'MGI', 'db_id': 'MGI:95773'},
#     {'db': 'UniGene', 'db_id': 'Mm.271703'},
#     {'db': 'UniGene', 'db_id': 'Mm.469993'}]}},
#  70: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 108107280,
#    'end': 108146146,
#    'strand': '-',
#    'ensembl_version': '4',
#    'symbol': 'Gnai3',
#    'name': 'guanine nucleotide binding protein (G protein), alpha inhibiting 3',
#    'synonyms': ['AI158965', 'AW537698', 'Galphai3', 'Gnai-3', 'Galphai3'],
#    'external_ids': [{'db': 'EntrezGene', 'db_id': '14679'},
#     {'db': 'MGI', 'db_id': 'MGI:95773'},
#     {'db': 'UniGene', 'db_id': 'Mm.271703'},
#     {'db': 'UniGene', 'db_id': 'Mm.391725'},
#     {'db': 'UniGene', 'db_id': 'Mm.469993'}]}},
#  71: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 108107280,
#    'end': 108146146,
#    'strand': '-',
#    'ensembl_version': '4',
#    'symbol': 'Gnai3',
#    'name': 'guanine nucleotide binding protein (G protein), alpha inhibiting 3',
#    'synonyms': ['AI158965', 'AW537698', 'Galphai3', 'Gnai-3', 'Galphai3'],
#    'external_ids': [{'db': 'EntrezGene', 'db_id': '14679'},
#     {'db': 'MGI', 'db_id': 'MGI:95773'},
#     {'db': 'UniGene', 'db_id': 'Mm.271703'},
#     {'db': 'UniGene', 'db_id': 'Mm.391725'},
#     {'db': 'UniGene', 'db_id': 'Mm.469993'}]}},
#  72: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 108107280,
#    'end': 108146146,
#    'strand': '-',
#    'ensembl_version': '4',
#    'symbol': 'Gnai3',
#    'name': 'guanine nucleotide binding protein (G protein), alpha inhibiting 3',
#    'synonyms': ['AI158965', 'AW537698', 'Galphai3', 'Gnai-3', 'Galphai3'],
#    'external_ids': [{'db': 'EntrezGene', 'db_id': '14679'},
#     {'db': 'MGI', 'db_id': 'MGI:95773'},
#     {'db': 'UniGene', 'db_id': 'Mm.271703'},
#     {'db': 'UniGene', 'db_id': 'Mm.391725'},
#     {'db': 'UniGene', 'db_id': 'Mm.469993'}]}},
#  73: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 108107280,
#    'end': 108146146,
#    'strand': '-',
#    'ensembl_version': '4',
#    'symbol': 'Gnai3',
#    'name': 'guanine nucleotide binding protein (G protein), alpha inhibiting 3',
#    'synonyms': ['AI158965', 'AW537698', 'Galphai3', 'Gnai-3', 'Galphai3'],
#    'external_ids': [{'db': 'EntrezGene', 'db_id': '14679'},
#     {'db': 'MGI', 'db_id': 'MGI:95773'},
#     {'db': 'UniGene', 'db_id': 'Mm.271703'},
#     {'db': 'UniGene', 'db_id': 'Mm.391725'},
#     {'db': 'UniGene', 'db_id': 'Mm.469993'}]}},
#  74: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 108107280,
#    'end': 108146146,
#    'strand': '-',
#    'ensembl_version': '4',
#    'symbol': 'Gnai3',
#    'name': 'guanine nucleotide binding protein (G protein), alpha inhibiting 3',
#    'synonyms': ['AI158965', 'AW537698', 'Galphai3', 'Gnai-3', 'Galphai3'],
#    'external_ids': [{'db': 'EntrezGene', 'db_id': '14679'},
#     {'db': 'MGI', 'db_id': 'MGI:95773'},
#     {'db': 'UniGene', 'db_id': 'Mm.271703'},
#     {'db': 'UniGene', 'db_id': 'Mm.391725'},
#     {'db': 'UniGene', 'db_id': 'Mm.469993'}]}},
#  75: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 108107280,
#    'end': 108146146,
#    'strand': '-',
#    'ensembl_version': '4',
#    'symbol': 'Gnai3',
#    'name': 'guanine nucleotide binding protein (G protein), alpha inhibiting 3',
#    'synonyms': ['AI158965', 'AW537698', 'Galphai3', 'Gnai-3', 'Galphai3'],
#    'external_ids': [{'db': 'EntrezGene', 'db_id': '14679'},
#     {'db': 'MGI', 'db_id': 'MGI:95773'},
#     {'db': 'UniGene', 'db_id': 'Mm.271703'},
#     {'db': 'UniGene', 'db_id': 'Mm.391725'},
#     {'db': 'UniGene', 'db_id': 'Mm.469993'}]}},
#  76: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 108107280,
#    'end': 108146146,
#    'strand': '-',
#    'ensembl_version': '4',
#    'symbol': 'Gnai3',
#    'name': 'guanine nucleotide binding protein (G protein), alpha inhibiting 3',
#    'synonyms': ['AI158965', 'AW537698', 'Galphai3', 'Gnai-3', 'Galphai3'],
#    'external_ids': [{'db': 'EntrezGene', 'db_id': '14679'},
#     {'db': 'MGI', 'db_id': 'MGI:95773'},
#     {'db': 'UniGene', 'db_id': 'Mm.271703'},
#     {'db': 'UniGene', 'db_id': 'Mm.391725'},
#     {'db': 'UniGene', 'db_id': 'Mm.469993'}]}},
#  77: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 108107280,
#    'end': 108146146,
#    'strand': '-',
#    'ensembl_version': '4',
#    'symbol': 'Gnai3',
#    'name': 'guanine nucleotide binding protein (G protein), alpha inhibiting 3',
#    'synonyms': ['AI158965', 'AW537698', 'Galphai3', 'Gnai-3', 'Galphai3'],
#    'external_ids': [{'db': 'EntrezGene', 'db_id': '14679'},
#     {'db': 'MGI', 'db_id': 'MGI:95773'},
#     {'db': 'UniGene', 'db_id': 'Mm.271703'},
#     {'db': 'UniGene', 'db_id': 'Mm.391725'},
#     {'db': 'UniGene', 'db_id': 'Mm.469993'}]}},
#  78: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 108107280,
#    'end': 108146146,
#    'strand': '-',
#    'ensembl_version': '4',
#    'symbol': 'Gnai3',
#    'name': 'guanine nucleotide binding protein (G protein), alpha inhibiting 3',
#    'synonyms': ['AI158965', 'AW537698', 'Galphai3', 'Gnai-3', 'Galphai3'],
#    'external_ids': [{'db': 'EntrezGene', 'db_id': '14679'},
#     {'db': 'MGI', 'db_id': 'MGI:95773'},
#     {'db': 'UniGene', 'db_id': 'Mm.271703'},
#     {'db': 'UniGene', 'db_id': 'Mm.391725'},
#     {'db': 'UniGene', 'db_id': 'Mm.469993'}]}},
#  79: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 108107280,
#    'end': 108146146,
#    'strand': '-',
#    'ensembl_version': '4',
#    'symbol': 'Gnai3',
#    'name': 'guanine nucleotide binding protein (G protein), alpha inhibiting 3',
#    'synonyms': ['AI158965', 'AW537698', 'Galphai3', 'Gnai-3', 'Galphai3'],
#    'external_ids': [{'db': 'EntrezGene', 'db_id': '14679'},
#     {'db': 'MGI', 'db_id': 'MGI:95773'},
#     {'db': 'UniGene', 'db_id': 'Mm.271703'},
#     {'db': 'UniGene', 'db_id': 'Mm.391725'},
#     {'db': 'UniGene', 'db_id': 'Mm.469993'}]}},
#  80: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 108107280,
#    'end': 108146146,
#    'strand': '-',
#    'ensembl_version': '4',
#    'symbol': 'Gnai3',
#    'name': 'guanine nucleotide binding protein (G protein), alpha inhibiting 3',
#    'synonyms': ['AI158965', 'AW537698', 'Galphai3', 'Gnai-3', 'Galphai3'],
#    'external_ids': [{'db': 'EntrezGene', 'db_id': '14679'},
#     {'db': 'MGI', 'db_id': 'MGI:95773'},
#     {'db': 'UniGene', 'db_id': 'Mm.271703'}]}},
#  81: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 108107280,
#    'end': 108146146,
#    'strand': '-',
#    'ensembl_version': '4',
#    'symbol': 'Gnai3',
#    'name': 'guanine nucleotide binding protein (G protein), alpha inhibiting 3',
#    'synonyms': ['AI158965', 'AW537698', 'Galphai3', 'Gnai-3', 'Galphai3'],
#    'external_ids': [{'db': 'EntrezGene', 'db_id': '14679'},
#     {'db': 'MGI', 'db_id': 'MGI:95773'},
#     {'db': 'UniGene', 'db_id': 'Mm.271703'}]}},
#  82: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 108107280,
#    'end': 108146146,
#    'strand': '-',
#    'ensembl_version': '4',
#    'symbol': 'Gnai3',
#    'name': 'guanine nucleotide binding protein (G protein), alpha inhibiting 3',
#    'synonyms': ['AI158965', 'AW537698', 'Galphai3', 'Gnai-3', 'Galphai3'],
#    'external_ids': [{'db': 'EntrezGene', 'db_id': '14679'},
#     {'db': 'MGI', 'db_id': 'MGI:95773'},
#     {'db': 'UniGene', 'db_id': 'Mm.271703'}]}},
#  83: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 108107280,
#    'end': 108146146,
#    'strand': '-',
#    'ensembl_version': '4',
#    'symbol': 'Gnai3',
#    'name': 'guanine nucleotide binding protein (G protein), alpha inhibiting 3',
#    'synonyms': ['AI158965', 'AW537698', 'Galphai3', 'Gnai-3', 'Galphai3'],
#    'external_ids': [{'db': 'EntrezGene', 'db_id': '14679'},
#     {'db': 'MGI', 'db_id': 'MGI:95773'},
#     {'db': 'UniGene', 'db_id': 'Mm.271703'}]}},
#  84: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 108107280,
#    'end': 108146146,
#    'strand': '-',
#    'ensembl_version': '4',
#    'symbol': 'Gnai3',
#    'name': 'guanine nucleotide binding protein (G protein), alpha inhibiting 3',
#    'synonyms': ['AI158965', 'AW537698', 'Galphai3', 'Gnai-3', 'Galphai3'],
#    'external_ids': [{'db': 'EntrezGene', 'db_id': '14679'},
#     {'db': 'MGI', 'db_id': 'MGI:95773'},
#     {'db': 'UniGene', 'db_id': 'Mm.271703'}]}},
#  85: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 108107280,
#    'end': 108146146,
#    'strand': '-',
#    'ensembl_version': '4',
#    'symbol': 'Gnai3',
#    'name': 'guanine nucleotide binding protein (G protein), alpha inhibiting 3',
#    'synonyms': ['Galphai3'],
#    'external_ids': [{'db': 'EntrezGene', 'db_id': '14679'},
#     {'db': 'MGI', 'db_id': 'MGI:95773'},
#     {'db': 'UniGene', 'db_id': 'Mm.271703'}]}},
#  86: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 108107280,
#    'end': 108146146,
#    'strand': '-',
#    'ensembl_version': '4',
#    'symbol': 'Gnai3',
#    'name': 'guanine nucleotide binding protein (G protein), alpha inhibiting 3',
#    'synonyms': ['AI158965', 'AW537698', 'Galphai3', 'Gnai-3', 'Galphai3'],
#    'external_ids': [{'db': 'EntrezGene', 'db_id': '14679'},
#     {'db': 'MGI', 'db_id': 'MGI:95773'},
#     {'db': 'UniGene', 'db_id': 'Mm.271703'}]}},
#  87: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 108107280,
#    'end': 108146146,
#    'strand': '-',
#    'ensembl_version': '4',
#    'symbol': 'Gnai3',
#    'name': 'guanine nucleotide binding protein (G protein), alpha inhibiting 3',
#    'synonyms': ['AI158965', 'AW537698', 'Galphai3', 'Gnai-3', 'Galphai3'],
#    'external_ids': [{'db': 'EntrezGene', 'db_id': '14679'},
#     {'db': 'MGI', 'db_id': 'MGI:95773'},
#     {'db': 'UniGene', 'db_id': 'Mm.271703'}]}},
#  88: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 108107280,
#    'end': 108146146,
#    'strand': '-',
#    'ensembl_version': '4',
#    'symbol': 'Gnai3',
#    'name': 'guanine nucleotide binding protein (G protein), alpha inhibiting 3',
#    'synonyms': ['Galphai3'],
#    'external_ids': [{'db': 'EntrezGene', 'db_id': '14679'},
#     {'db': 'MGI', 'db_id': 'MGI:95773'},
#     {'db': 'UniGene', 'db_id': 'Mm.271703'}]}},
#  89: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 108107280,
#    'end': 108146146,
#    'strand': '-',
#    'ensembl_version': '4',
#    'symbol': 'Gnai3',
#    'name': 'guanine nucleotide binding protein (G protein), alpha inhibiting 3',
#    'synonyms': ['Galphai3'],
#    'external_ids': [{'db': 'EntrezGene', 'db_id': '14679'},
#     {'db': 'MGI', 'db_id': 'MGI:95773'},
#     {'db': 'UniGene', 'db_id': 'Mm.271703'}]}},
#  90: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 108107280,
#    'end': 108146146,
#    'strand': '-',
#    'ensembl_version': '4',
#    'symbol': 'Gnai3',
#    'name': 'guanine nucleotide binding protein (G protein), alpha inhibiting 3',
#    'synonyms': ['Galphai3'],
#    'external_ids': [{'db': 'EntrezGene', 'db_id': '14679'},
#     {'db': 'MGI', 'db_id': 'MGI:95773'},
#     {'db': 'UniGene', 'db_id': 'Mm.271703'}]}},
#  91: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 108107280,
#    'end': 108146146,
#    'strand': '-',
#    'ensembl_version': '4',
#    'symbol': 'Gnai3',
#    'name': 'guanine nucleotide binding protein (G protein), alpha inhibiting 3',
#    'synonyms': ['Galphai3'],
#    'external_ids': [{'db': 'EntrezGene', 'db_id': '14679'},
#     {'db': 'MGI', 'db_id': 'MGI:95773'},
#     {'db': 'UniGene', 'db_id': 'Mm.271703'}]}},
#  92: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 108107280,
#    'end': 108146146,
#    'strand': '-',
#    'ensembl_version': '4',
#    'symbol': 'Gnai3',
#    'name': 'guanine nucleotide binding protein (G protein), alpha inhibiting 3',
#    'synonyms': ['Galphai3'],
#    'external_ids': [{'db': 'EntrezGene', 'db_id': '14679'},
#     {'db': 'MGI', 'db_id': 'MGI:95773'}]}},
#  93: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 108107280,
#    'end': 108146146,
#    'strand': '-',
#    'ensembl_version': '4',
#    'symbol': 'Gnai3',
#    'name': 'guanine nucleotide binding protein (G protein), alpha inhibiting 3',
#    'synonyms': ['Galphai3'],
#    'external_ids': [{'db': 'EntrezGene', 'db_id': '14679'},
#     {'db': 'MGI', 'db_id': 'MGI:95773'}]}},
#  94: {'ENSMUSG00000000001': {'id': 'ENSMUSG00000000001',
#    'species_id': 'Mm',
#    'chromosome': '3',
#    'start': 108107280,
#    'end': 108146146,
#    'strand': '-',
#    'ensembl_version': '4',
#    'symbol': 'Gnai3',
#    'name': 'guanine nucleotide binding protein (G protein), alpha inhibiting 3',
#    'synonyms': ['Galphai3'],
#    'external_ids': [{'db': 'EntrezGene', 'db_id': '14679'},
#     {'db': 'MGI', 'db_id': 'MGI:95773'}]}}}
